# %%
import pandas as pd

# %%
# The path to our CSV file
file = "analyst_ratings_processed.csv"

# Read our Kickstarter data into pandas
headlines = pd.read_csv(file)
headlines.head(20)
# Out:
#     Unnamed: 0                                              title  \
# 0          0.0            Stocks That Hit 52-Week Highs On Friday
# 1          1.0         Stocks That Hit 52-Week Highs On Wednesday
# 2          2.0                      71 Biggest Movers From Friday
# 3          3.0       46 Stocks Moving In Friday's Mid-Day Session
# 4          4.0  B of A Securities Maintains Neutral on Agilent...
# 5          5.0  CFRA Maintains Hold on Agilent Technologies, L...
# 6          6.0  UBS Maintains Neutral on Agilent Technologies,...
# 7          7.0  Agilent Technologies shares are trading higher...
# 8          8.0  Wells Fargo Maintains Overweight on Agilent Te...
# 9          9.0         10 Biggest Price Target Changes For Friday
# 10        10.0    30 Stocks Moving in Friday's Pre-Market Session
# 11        11.0  SVB Leerink Maintains Outperform on Agilent Te...
# 12        12.0  8 Stocks Moving In Thursday's After-Hours Session
# ...

# %%
# Get a list of all of our columns for easy reference
headlines.columns
# Out:
# Index(['Unnamed: 0', 'title', 'date', 'stock'], dtype='object')

# %%
# The path to our CSV file
sp500listing = "sp500listing.csv"

# Read our Kickstarter data into pandas
sp500 = pd.read_csv(sp500listing)
sp500.head(20)
# Out:
#    Symbol                         Security
# 0     MMM                               3M
# 1     ABT              Abbott Laboratories
# 2    ABBV                           AbbVie
# 3    ABMD                          Abiomed
# 4     ACN                        Accenture
# 5    ATVI              Activision Blizzard
# 6    ADBE                            Adobe
# 7     AMD           Advanced Micro Devices
# 8     AAP               Advance Auto Parts
# 9     AES                         AES Corp
# 10    AFL                            Aflac
# 11      A             Agilent Technologies
# 12    APD         Air Products & Chemicals
# 13   AKAM              Akamai Technologies
# 14    ALK                 Alaska Air Group
# 15    ALB            Albemarle Corporation
# 16    ARE  Alexandria Real Estate Equities
# 17   ALGN                 Align Technology
# 18   ALLE                         Allegion
# 19    LNT                   Alliant Energy

# %%
slim = headlines.merge(sp500, left_on='stock', right_on='Symbol')

# %%
print(slim)
# Out:
#         Unnamed: 0                                              title  \
# 0              0.0            Stocks That Hit 52-Week Highs On Friday
# 1              1.0         Stocks That Hit 52-Week Highs On Wednesday
# 2              2.0                      71 Biggest Movers From Friday
# 3              3.0       46 Stocks Moving In Friday's Mid-Day Session
# 4              4.0  B of A Securities Maintains Neutral on Agilent...
# ...            ...                                                ...
# 347625   1412661.0  IPO for Pfizer's Zoetis Prices 86.1M Shares at...
# 347626   1412662.0  ISI Group Initiates Coverage on Zoetis at Buy,...
# 347627   1412663.0  Pfizer, Spinoff Zoetis Receive Positive Mad Mo...
# 347628   1412664.0                        Will These 2 IPOs Flourish?
# 347629   1412665.0  UPDATE: Pfizer's Zoetis to Offer 86.1M Shares,...
#
#                              date stock Symbol              Security
# ...

# %%
slim.to_csv(r"slim.csv", index=False, header=True)
