# %%
# Import Dependencies
import pandas as pd

# %%
# Make a reference to the weekly data file path
csv_path = "weekly_data.csv"

# Import the csv file as a DataFrame
weekly = pd.read_csv(csv_path, index_col = 0)
weekly.head()
# Out:
#   Ticker       Open      Close  Year  Week  Prediction
# 0      A  30.650000  29.980000  2010     6         1.0
# 1      A  30.359999  30.630001  2010     7         1.0
# 2      A  33.199999  33.580001  2010    10         1.0
# 3      A  33.780000  34.310001  2010    12         1.0
# 4      A  35.380001  36.289999  2010    16         0.0

# %%
html = weekly.to_html(index=False, na_rep='NaN', sparsify=None, index_names=True, justify=None, bold_rows=True, 
               classes="container-float", escape=True, show_dimensions=False, notebook=False)

# %%
text_file = open("WeeklyData.html", "w")
text_file.write(html)
text_file.close()

# %%
# First and ten, do it again.

# %%
# Make a reference to the S&P data file path
csv_path = "sandp_data_final.csv"

# Import the csv file as a DataFrame
snp = pd.read_csv(csv_path)
snp
# Out:
#                                                     title  \
# 0                 Stocks That Hit 52-Week Highs On Friday
# 1              Stocks That Hit 52-Week Highs On Wednesday
# 2                           71 Biggest Movers From Friday
# 3             46 Stocks Moving In Fridays Mid-Day Session
# 4       B of A Securities Maintains Neutral on Agilent...
# ...                                                   ...
# 303230  IPO for Pfizers Zoetis Prices 86.1M Shares at ...
# 303231  ISI Group Initiates Coverage on Zoetis at Buy,...
# 303232  Pfizer, Spinoff Zoetis Receive Positive Mad Mo...
# 303233                        Will These 2 IPOs Flourish?
# 303234  UPDATE: Pfizers Zoetis to Offer 86.1M Shares, ...
#
#                              date stock  Subjectivity  Polarity  Predicted
# 0       2020-06-05 10:30:00-04:00     A        0.0000       1.0        1.0
# 1       2020-06-03 10:45:00-04:00     A        0.0000       1.0        1.0
# ...

# %%
html = snp.to_html(index=False, na_rep='NaN', sparsify=None, index_names=True, justify=None, bold_rows=True, 
               classes="container-float", escape=True, show_dimensions=False, notebook=False)

# %%
text_file = open("SandPData.html", "w")
text_file.write(html)
text_file.close()

# %%
snp_AtoC = snp.iloc[:74844,:]
snp_DtoI = snp.iloc[74845:152163,:]
snp_JtoN = snp.iloc[152164:228017,:]
snp_OtoZ = snp.iloc[228018:,:]

# %%
html = snp_AtoC.to_html(index=False, na_rep='NaN', sparsify=None, index_names=True, justify=None, bold_rows=True, 
               classes="container-float", escape=True, show_dimensions=False, notebook=False)
text_file = open("SnP_AtoC.html", "w")
text_file.write(html)
text_file.close()

# %%
html = snp_DtoI.to_html(index=False, na_rep='NaN', sparsify=None, index_names=True, justify=None, bold_rows=True, 
               classes="container-float", escape=True, show_dimensions=False, notebook=False)
text_file = open("SnP_DtoI.html", "w")
text_file.write(html)
text_file.close()

# %%
html = snp_JtoN.to_html(index=False, na_rep='NaN', sparsify=None, index_names=True, justify=None, bold_rows=True, 
               classes="container-float", escape=True, show_dimensions=False, notebook=False)
text_file = open("SnP_JtoN.html", "w")
text_file.write(html)
text_file.close()

# %%
html = snp_OtoZ.to_html(index=False, na_rep='NaN', sparsify=None, index_names=True, justify=None, bold_rows=True, 
               classes="container-float", escape=True, show_dimensions=False, notebook=False)
text_file = open("SnP_OtoZ.html", "w")
text_file.write(html)
text_file.close()
